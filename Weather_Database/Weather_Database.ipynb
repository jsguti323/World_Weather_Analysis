# %%
# Important Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import random
from config import weather_api_key
import time

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)
coordinates = list(coordinates)

# %%
# Generate the nearest city using the CityPy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve relevant data from cities.
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

    # If an error is experienced, skip the city.
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san policarpo
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | kruisfontein
# Processing Record 8 of Set 1 | kismayo
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | clyde river
# Processing Record 11 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | port blair
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | blackfoot
# Processing Record 19 of Set 1 | mandali
# Processing Record 20 of Set 1 | ahipara
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 1 | suna
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | havoysund
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | new glasgow
# Processing Record 32 of Set 1 | port lincoln
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | banes
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | pulandian
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | seredka
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | chifeng
# Processing Record 43 of Set 1 | plettenberg bay
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | kysyl-syr
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | boyolangu
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | maumere
# Processing Record 2 of Set 2 | northam
# Processing Record 3 of Set 2 | rassvet
# Processing Record 4 of Set 2 | punta de bombon
# Processing Record 5 of Set 2 | peleduy
# Processing Record 6 of Set 2 | alekseyevsk
# Processing Record 7 of Set 2 | merauke
# Processing Record 8 of Set 2 | corrente
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | kandrian
# Processing Record 11 of Set 2 | rocha
# Processing Record 12 of Set 2 | manzanillo
# Processing Record 13 of Set 2 | waipawa
# Processing Record 14 of Set 2 | kavieng
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | ondjiva
# Processing Record 17 of Set 2 | klaksvik
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | lipin bor
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | sobolevo
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | alashtar
# City not found. Skipping...
# Processing Record 24 of Set 2 | te anau
# Processing Record 25 of Set 2 | zhangjiakou
# Processing Record 26 of Set 2 | san quintin
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | baghdad
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | belyy yar
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 2 | sakaiminato
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | santa cruz
# Processing Record 42 of Set 2 | praia
# Processing Record 43 of Set 2 | roebourne
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | hershey
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | carnot
# Processing Record 48 of Set 2 | thunder bay
# Processing Record 49 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 50 of Set 2 | marabba
# Processing Record 1 of Set 3 | isangel
# Processing Record 2 of Set 3 | pundaguitan
# Processing Record 3 of Set 3 | la ronge
# Processing Record 4 of Set 3 | newport
# Processing Record 5 of Set 3 | usvyaty
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | naryan-mar
# Processing Record 8 of Set 3 | monte patria
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | geraldton
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | nanortalik
# Processing Record 13 of Set 3 | auki
# Processing Record 14 of Set 3 | tawzar
# City not found. Skipping...
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | gizo
# Processing Record 17 of Set 3 | ahar
# Processing Record 18 of Set 3 | esperance
# Processing Record 19 of Set 3 | cachoeirinha
# Processing Record 20 of Set 3 | klyuchi
# Processing Record 21 of Set 3 | bindi
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | aklavik
# Processing Record 25 of Set 3 | tautira
# Processing Record 26 of Set 3 | makakilo city
# Processing Record 27 of Set 3 | grindavik
# Processing Record 28 of Set 3 | laguna
# Processing Record 29 of Set 3 | cozumel
# Processing Record 30 of Set 3 | tessalit
# Processing Record 31 of Set 3 | bandarbeyla
# Processing Record 32 of Set 3 | sao jose da coroa grande
# Processing Record 33 of Set 3 | ukiah
# Processing Record 34 of Set 3 | yerbogachen
# Processing Record 35 of Set 3 | norman wells
# Processing Record 36 of Set 3 | jibuti
# Processing Record 37 of Set 3 | sorland
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | luderitz
# Processing Record 40 of Set 3 | shiraz
# Processing Record 41 of Set 3 | gberia fotombu
# Processing Record 42 of Set 3 | aykhal
# Processing Record 43 of Set 3 | berdigestyakh
# Processing Record 44 of Set 3 | klishkivtsi
# Processing Record 45 of Set 3 | puerto escondido
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | arman
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | intipuca
# Processing Record 50 of Set 3 | galbshtadt
# Processing Record 1 of Set 4 | yerofey pavlovich
# Processing Record 2 of Set 4 | ust-karsk
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | montrose
# Processing Record 7 of Set 4 | gigmoto
# Processing Record 8 of Set 4 | arraial do cabo
# Processing Record 9 of Set 4 | hobyo
# Processing Record 10 of Set 4 | birjand
# Processing Record 11 of Set 4 | opuwo
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | cedar city
# Processing Record 14 of Set 4 | siguiri
# Processing Record 15 of Set 4 | strezhevoy
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | porto novo
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | solnechnyy
# Processing Record 20 of Set 4 | pincher creek
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 4 | astipalaia
# City not found. Skipping...
# Processing Record 24 of Set 4 | coquimbo
# Processing Record 25 of Set 4 | kaitangata
# Processing Record 26 of Set 4 | pacific grove
# Processing Record 27 of Set 4 | honningsvag
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | tura
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | severo-kurilsk
# Processing Record 32 of Set 4 | breves
# Processing Record 33 of Set 4 | lasa
# Processing Record 34 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 4 | kloulklubed
# Processing Record 36 of Set 4 | winton
# Processing Record 37 of Set 4 | siwana
# Processing Record 38 of Set 4 | vila franca do campo
# Processing Record 39 of Set 4 | zyryanskoye
# Processing Record 40 of Set 4 | usinsk
# Processing Record 41 of Set 4 | college
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | general roca
# Processing Record 44 of Set 4 | hegra
# Processing Record 45 of Set 4 | bozoum
# Processing Record 46 of Set 4 | bengkulu
# Processing Record 47 of Set 4 | chokurdakh
# Processing Record 48 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 4 | yulara
# Processing Record 50 of Set 4 | buin
# Processing Record 1 of Set 5 | asau
# Processing Record 2 of Set 5 | bandar-e anzali
# Processing Record 3 of Set 5 | salvador
# Processing Record 4 of Set 5 | richards bay
# Processing Record 5 of Set 5 | kerema
# Processing Record 6 of Set 5 | padang
# Processing Record 7 of Set 5 | narsaq
# Processing Record 8 of Set 5 | port-gentil
# Processing Record 9 of Set 5 | chippenham
# Processing Record 10 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 5 | hammerfest
# Processing Record 12 of Set 5 | broome
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | alta floresta
# Processing Record 15 of Set 5 | maridi
# Processing Record 16 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 5 | codrington
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | pascagoula
# Processing Record 20 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 5 | yumen
# Processing Record 22 of Set 5 | sivas
# Processing Record 23 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 5 | delijan
# Processing Record 25 of Set 5 | malinovoye ozero
# Processing Record 26 of Set 5 | panama city
# Processing Record 27 of Set 5 | comodoro rivadavia
# Processing Record 28 of Set 5 | salalah
# Processing Record 29 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 30 of Set 5 | voznesenye
# Processing Record 31 of Set 5 | carballo
# Processing Record 32 of Set 5 | sao filipe
# Processing Record 33 of Set 5 | elk city
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | sylva
# Processing Record 37 of Set 5 | dovers
# Processing Record 38 of Set 5 | portales
# Processing Record 39 of Set 5 | erenhot
# Processing Record 40 of Set 5 | axim
# Processing Record 41 of Set 5 | portland
# Processing Record 42 of Set 5 | adrar
# Processing Record 43 of Set 5 | shimoda
# Processing Record 44 of Set 5 | oxford
# Processing Record 45 of Set 5 | mount gambier
# Processing Record 46 of Set 5 | sobolivka
# Processing Record 47 of Set 5 | tshikapa
# Processing Record 48 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 5 | manicore
# Processing Record 50 of Set 5 | nuuk
# Processing Record 1 of Set 6 | mnogovershinnyy
# Processing Record 2 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 3 of Set 6 | cayenne
# Processing Record 4 of Set 6 | kurilsk
# Processing Record 5 of Set 6 | weligama
# Processing Record 6 of Set 6 | cicero dantas
# Processing Record 7 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 6 | turukhansk
# Processing Record 9 of Set 6 | nouadhibou
# Processing Record 10 of Set 6 | kodinsk
# Processing Record 11 of Set 6 | obu
# Processing Record 12 of Set 6 | idukki
# Processing Record 13 of Set 6 | churapcha
# Processing Record 14 of Set 6 | istiaia
# Processing Record 15 of Set 6 | anadyr
# Processing Record 16 of Set 6 | wuxue
# Processing Record 17 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 6 | kirakira
# Processing Record 19 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 20 of Set 6 | paraiso
# Processing Record 21 of Set 6 | ancud
# Processing Record 22 of Set 6 | fortuna
# Processing Record 23 of Set 6 | bhagalpur
# Processing Record 24 of Set 6 | pemangkat
# Processing Record 25 of Set 6 | cuamba
# Processing Record 26 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 6 | saint-philippe
# Processing Record 28 of Set 6 | zhigansk
# Processing Record 29 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 30 of Set 6 | nome
# Processing Record 31 of Set 6 | los alamos
# Processing Record 32 of Set 6 | havre-saint-pierre
# Processing Record 33 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 6 | luis correia
# Processing Record 35 of Set 6 | morros
# Processing Record 36 of Set 6 | yuanping
# Processing Record 37 of Set 6 | caohai
# Processing Record 38 of Set 6 | sao joao da ponte
# Processing Record 39 of Set 6 | porosozero
# Processing Record 40 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 41 of Set 6 | pimentel
# Processing Record 42 of Set 6 | kampong thum
# Processing Record 43 of Set 6 | ylivieska
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | flinders
# Processing Record 46 of Set 6 | lugus
# Processing Record 47 of Set 6 | ajaccio
# Processing Record 48 of Set 6 | belaya gora
# Processing Record 49 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 7 | plotnikovo
# Processing Record 2 of Set 7 | barra do bugres
# Processing Record 3 of Set 7 | nacala
# Processing Record 4 of Set 7 | cockburn town
# Processing Record 5 of Set 7 | okha
# Processing Record 6 of Set 7 | beziers
# Processing Record 7 of Set 7 | ipixuna
# Processing Record 8 of Set 7 | warmbad
# Processing Record 9 of Set 7 | naze
# Processing Record 10 of Set 7 | belmonte
# Processing Record 11 of Set 7 | cap malheureux
# Processing Record 12 of Set 7 | kalabo
# Processing Record 13 of Set 7 | camabatela
# Processing Record 14 of Set 7 | viedma
# Processing Record 15 of Set 7 | zhengjiatun
# Processing Record 16 of Set 7 | olafsvik
# Processing Record 17 of Set 7 | fort nelson
# Processing Record 18 of Set 7 | itoman
# Processing Record 19 of Set 7 | winnemucca
# Processing Record 20 of Set 7 | constitucion
# Processing Record 21 of Set 7 | mao
# Processing Record 22 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 7 | jacareacanga
# Processing Record 24 of Set 7 | khoy
# Processing Record 25 of Set 7 | ornskoldsvik
# Processing Record 26 of Set 7 | lompoc
# Processing Record 27 of Set 7 | raga
# Processing Record 28 of Set 7 | kudahuvadhoo
# Processing Record 29 of Set 7 | paamiut
# Processing Record 30 of Set 7 | leningradskiy
# Processing Record 31 of Set 7 | tuatapere
# Processing Record 32 of Set 7 | mtsamboro
# Processing Record 33 of Set 7 | praia da vitoria
# Processing Record 34 of Set 7 | key west
# Processing Record 35 of Set 7 | fairbanks
# Processing Record 36 of Set 7 | camacha
# Processing Record 37 of Set 7 | painesville
# Processing Record 38 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 7 | touros
# Processing Record 41 of Set 7 | quatre cocos
# Processing Record 42 of Set 7 | mataram
# Processing Record 43 of Set 7 | olenegorsk
# Processing Record 44 of Set 7 | jingdezhen
# Processing Record 45 of Set 7 | altar
# Processing Record 46 of Set 7 | alice
# Processing Record 47 of Set 7 | santos dumont
# Processing Record 48 of Set 7 | dubenskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | mancora
# Processing Record 50 of Set 7 | cherskiy
# Processing Record 1 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 8 | westport
# Processing Record 3 of Set 8 | potgietersrus
# City not found. Skipping...
# Processing Record 4 of Set 8 | maunabo
# Processing Record 5 of Set 8 | ljungby
# Processing Record 6 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 8 | chicama
# Processing Record 8 of Set 8 | grimari
# City not found. Skipping...
# Processing Record 9 of Set 8 | mayo
# Processing Record 10 of Set 8 | ladozhskaya
# Processing Record 11 of Set 8 | tilichiki
# Processing Record 12 of Set 8 | kobojango
# City not found. Skipping...
# Processing Record 13 of Set 8 | oudtshoorn
# Processing Record 14 of Set 8 | vardo
# Processing Record 15 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 8 | rundu
# Processing Record 17 of Set 8 | vao
# Processing Record 18 of Set 8 | sakakah
# Processing Record 19 of Set 8 | isabela
# Processing Record 20 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 8 | kulu
# Processing Record 22 of Set 8 | manokwari
# Processing Record 23 of Set 8 | sao felix do xingu
# Processing Record 24 of Set 8 | tomatlan
# Processing Record 25 of Set 8 | nemuro
# Processing Record 26 of Set 8 | broken hill
# Processing Record 27 of Set 8 | qaqortoq
# Processing Record 28 of Set 8 | diffa
# Processing Record 29 of Set 8 | koygorodok
# Processing Record 30 of Set 8 | juan lacaze
# Processing Record 31 of Set 8 | pangnirtung
# Processing Record 32 of Set 8 | kushima
# Processing Record 33 of Set 8 | gold coast
# Processing Record 34 of Set 8 | keflavik
# Processing Record 35 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 36 of Set 8 | kyabe
# Processing Record 37 of Set 8 | alice springs
# Processing Record 38 of Set 8 | baraboo
# Processing Record 39 of Set 8 | alamor
# Processing Record 40 of Set 8 | saint anthony
# Processing Record 41 of Set 8 | port-cartier
# Processing Record 42 of Set 8 | baoying
# Processing Record 43 of Set 8 | gatton
# Processing Record 44 of Set 8 | bartica
# Processing Record 45 of Set 8 | sergeyevka
# Processing Record 46 of Set 8 | tahoua
# Processing Record 47 of Set 8 | lazaro cardenas
# Processing Record 48 of Set 8 | promyshlennaya
# Processing Record 49 of Set 8 | payerne
# Processing Record 50 of Set 8 | vila velha
# Processing Record 1 of Set 9 | lagoa
# Processing Record 2 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 4 of Set 9 | marrakesh
# Processing Record 5 of Set 9 | trenggalek
# Processing Record 6 of Set 9 | darab
# Processing Record 7 of Set 9 | roald
# Processing Record 8 of Set 9 | san patricio
# Processing Record 9 of Set 9 | temixco
# Processing Record 10 of Set 9 | saint andrews
# Processing Record 11 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 9 | manggar
# Processing Record 14 of Set 9 | maniitsoq
# Processing Record 15 of Set 9 | nishihara
# Processing Record 16 of Set 9 | shillong
# Processing Record 17 of Set 9 | casma
# Processing Record 18 of Set 9 | ajdabiya
# Processing Record 19 of Set 9 | chipinge
# Processing Record 20 of Set 9 | zyryanka
# Processing Record 21 of Set 9 | amurzet
# Processing Record 22 of Set 9 | nandura
# Processing Record 23 of Set 9 | souillac
# Processing Record 24 of Set 9 | eirunepe
# Processing Record 25 of Set 9 | akyab
# Processing Record 26 of Set 9 | san carlos del zulia
# Processing Record 27 of Set 9 | takoradi
# Processing Record 28 of Set 9 | obera
# Processing Record 29 of Set 9 | fonte boa
# Processing Record 30 of Set 9 | jutai
# Processing Record 31 of Set 9 | acapulco
# Processing Record 32 of Set 9 | steinbach
# Processing Record 33 of Set 9 | amuntai
# Processing Record 34 of Set 9 | jacmel
# Processing Record 35 of Set 9 | sosnovo-ozerskoye
# Processing Record 36 of Set 9 | kahramanmaras
# Processing Record 37 of Set 9 | palauig
# Processing Record 38 of Set 9 | sechura
# Processing Record 39 of Set 9 | kasongo-lunda
# Processing Record 40 of Set 9 | quballat
# Processing Record 41 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 9 | xunchang
# Processing Record 43 of Set 9 | neuquen
# Processing Record 44 of Set 9 | green valley
# Processing Record 45 of Set 9 | udachnyy
# Processing Record 46 of Set 9 | khilok
# Processing Record 47 of Set 9 | road town
# Processing Record 48 of Set 9 | ketchikan
# Processing Record 49 of Set 9 | marzuq
# Processing Record 50 of Set 9 | omboue
# Processing Record 1 of Set 10 | soderhamn
# Processing Record 2 of Set 10 | salinopolis
# Processing Record 3 of Set 10 | san cristobal
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | asosa
# Processing Record 6 of Set 10 | massafra
# Processing Record 7 of Set 10 | rio gallegos
# Processing Record 8 of Set 10 | kisangani
# Processing Record 9 of Set 10 | mocuba
# Processing Record 10 of Set 10 | jieshi
# Processing Record 11 of Set 10 | olymskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | shubarshi
# Processing Record 13 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 14 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 10 | matara
# Processing Record 16 of Set 10 | vikulovo
# Processing Record 17 of Set 10 | iqaluit
# Processing Record 18 of Set 10 | biloela
# Processing Record 19 of Set 10 | nalut
# Processing Record 20 of Set 10 | maneadero
# Processing Record 21 of Set 10 | cabedelo
# Processing Record 22 of Set 10 | kieta
# Processing Record 23 of Set 10 | argelia
# Processing Record 24 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 10 | traverse city
# Processing Record 26 of Set 10 | lakeway
# Processing Record 27 of Set 10 | cascais
# Processing Record 28 of Set 10 | port hedland
# Processing Record 29 of Set 10 | batabano
# Processing Record 30 of Set 10 | igarka
# Processing Record 31 of Set 10 | yarada
# Processing Record 32 of Set 10 | burnie
# Processing Record 33 of Set 10 | lingao
# Processing Record 34 of Set 10 | craig
# Processing Record 35 of Set 10 | jalu
# Processing Record 36 of Set 10 | changli
# Processing Record 37 of Set 10 | verkhnyaya inta
# Processing Record 38 of Set 10 | ambilobe
# Processing Record 39 of Set 10 | lubao
# Processing Record 40 of Set 10 | deputatskiy
# Processing Record 41 of Set 10 | oktyabrskiy
# Processing Record 42 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 43 of Set 10 | phuthaditjhaba
# Processing Record 44 of Set 10 | leshukonskoye
# Processing Record 45 of Set 10 | kawambwa
# Processing Record 46 of Set 10 | srednekolymsk
# Processing Record 47 of Set 10 | jucurutu
# Processing Record 48 of Set 10 | talara
# Processing Record 49 of Set 10 | vanimo
# Processing Record 50 of Set 10 | iaciara
# Processing Record 1 of Set 11 | rutana
# Processing Record 2 of Set 11 | morro bay
# Processing Record 3 of Set 11 | sar-e pul
# Processing Record 4 of Set 11 | neiafu
# Processing Record 5 of Set 11 | goderich
# Processing Record 6 of Set 11 | teacapan
# Processing Record 7 of Set 11 | faanui
# Processing Record 8 of Set 11 | aransas pass
# Processing Record 9 of Set 11 | praxedis guerrero
# Processing Record 10 of Set 11 | inta
# Processing Record 11 of Set 11 | marsh harbour
# Processing Record 12 of Set 11 | msanga
# Processing Record 13 of Set 11 | abu dhabi
# Processing Record 14 of Set 11 | lai
# Processing Record 15 of Set 11 | chernyshevskiy
# Processing Record 16 of Set 11 | aquiraz
# Processing Record 17 of Set 11 | tual
# Processing Record 18 of Set 11 | walvis bay
# Processing Record 19 of Set 11 | penzance
# Processing Record 20 of Set 11 | luanda
# Processing Record 21 of Set 11 | yar-sale
# Processing Record 22 of Set 11 | kyzyl-suu
# Processing Record 23 of Set 11 | jardim
# Processing Record 24 of Set 11 | grand gaube
# Processing Record 25 of Set 11 | aguimes
# Processing Record 26 of Set 11 | sawtell
# Processing Record 27 of Set 11 | tosya
# Processing Record 28 of Set 11 | uong bi
# Processing Record 29 of Set 11 | glendive
# Processing Record 30 of Set 11 | mirnyy
# Processing Record 31 of Set 11 | guerrero negro
# Processing Record 32 of Set 11 | nurota
# Processing Record 33 of Set 11 | riyadh
# Processing Record 34 of Set 11 | norsup
# Processing Record 35 of Set 11 | hualmay
# Processing Record 36 of Set 11 | inhambane
# Processing Record 37 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 38 of Set 11 | nabire
# Processing Record 39 of Set 11 | cidreira
# Processing Record 40 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 11 | along
# Processing Record 42 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 11 | edd
# Processing Record 44 of Set 11 | grenfell
# Processing Record 45 of Set 11 | tortoli
# Processing Record 46 of Set 11 | darhan
# Processing Record 47 of Set 11 | salina cruz
# Processing Record 48 of Set 11 | moose factory
# Processing Record 49 of Set 11 | egvekinot
# Processing Record 50 of Set 11 | jiujiang
# Processing Record 1 of Set 12 | rabaul
# Processing Record 2 of Set 12 | birao
# Processing Record 3 of Set 12 | qandala
# Processing Record 4 of Set 12 | fukue
# Processing Record 5 of Set 12 | vila do maio
# Processing Record 6 of Set 12 | lufilufi
# Processing Record 7 of Set 12 | raudeberg
# Processing Record 8 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 12 | shingu
# Processing Record 10 of Set 12 | korla
# Processing Record 11 of Set 12 | saint-francois
# Processing Record 12 of Set 12 | valparaiso
# Processing Record 13 of Set 12 | margate
# Processing Record 14 of Set 12 | taksimo
# Processing Record 15 of Set 12 | abnub
# Processing Record 16 of Set 12 | henties bay
# Processing Record 17 of Set 12 | taizhou
# Processing Record 18 of Set 12 | general bravo
# Processing Record 19 of Set 12 | edgewater
# Processing Record 20 of Set 12 | farsund
# Processing Record 21 of Set 12 | mariental
# Processing Record 22 of Set 12 | izberbash
# Processing Record 23 of Set 12 | lesnoy
# Processing Record 24 of Set 12 | brazzaville
# Processing Record 25 of Set 12 | dunedin
# Processing Record 26 of Set 12 | maryborough
# Processing Record 27 of Set 12 | zinder
# Processing Record 28 of Set 12 | lorengau
# Processing Record 29 of Set 12 | labrea
# Processing Record 30 of Set 12 | nouakchott
# Processing Record 31 of Set 12 | maceio
# Processing Record 32 of Set 12 | guatire
# Processing Record 33 of Set 12 | sydney
# Processing Record 34 of Set 12 | bashmakovo
# Processing Record 35 of Set 12 | puerto guzman
# Processing Record 36 of Set 12 | rio grande
# Processing Record 37 of Set 12 | new iberia
# Processing Record 38 of Set 12 | narasapur
# Processing Record 39 of Set 12 | burica
# City not found. Skipping...
# Processing Record 40 of Set 12 | hohhot
# Processing Record 41 of Set 12 | necochea
# Processing Record 42 of Set 12 | muli
# Processing Record 43 of Set 12 | samarai
# Processing Record 44 of Set 12 | guariba
# Processing Record 45 of Set 12 | san jose
# Processing Record 46 of Set 12 | rognan
# Processing Record 47 of Set 12 | sinalunga
# Processing Record 48 of Set 12 | beeville
# Processing Record 49 of Set 12 | el dorado
# Processing Record 50 of Set 12 | escanaba
# Processing Record 1 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 13 | kottagudem
# Processing Record 3 of Set 13 | chernoyerkovskaya
# Processing Record 4 of Set 13 | kadoma
# Processing Record 5 of Set 13 | sayansk
# Processing Record 6 of Set 13 | bushehr
# Processing Record 7 of Set 13 | warrnambool
# Processing Record 8 of Set 13 | tooele
# Processing Record 9 of Set 13 | isla mujeres
# Processing Record 10 of Set 13 | melita
# Processing Record 11 of Set 13 | ormara
# Processing Record 12 of Set 13 | olga
# Processing Record 13 of Set 13 | lebyazhye
# Processing Record 14 of Set 13 | kiunga
# Processing Record 15 of Set 13 | valley city
# Processing Record 16 of Set 13 | benito juarez
# Processing Record 17 of Set 13 | montabaur
# Processing Record 18 of Set 13 | alyangula
# Processing Record 19 of Set 13 | tazovskiy
# Processing Record 20 of Set 13 | hereford
# Processing Record 21 of Set 13 | chumikan
# Processing Record 22 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 13 | vila
# Processing Record 24 of Set 13 | lerwick
# Processing Record 25 of Set 13 | port macquarie
# Processing Record 26 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 13 | agnibilekrou
# Processing Record 28 of Set 13 | minna
# Processing Record 29 of Set 13 | pudozh
# Processing Record 30 of Set 13 | katsuura
# Processing Record 31 of Set 13 | dombarovskiy
# Processing Record 32 of Set 13 | koindu
# Processing Record 33 of Set 13 | quelimane
# Processing Record 34 of Set 13 | talaya
# Processing Record 35 of Set 13 | malacacheta
# Processing Record 36 of Set 13 | bar harbor
# Processing Record 37 of Set 13 | goure
# Processing Record 38 of Set 13 | slave lake
# Processing Record 39 of Set 13 | tirumullaivasal
# Processing Record 40 of Set 13 | springfield
# Processing Record 41 of Set 13 | kuandian
# Processing Record 42 of Set 13 | mitu
# Processing Record 43 of Set 13 | mananjary
# Processing Record 44 of Set 13 | innisfail
# Processing Record 45 of Set 13 | rincon
# Processing Record 46 of Set 13 | swellendam
# Processing Record 47 of Set 13 | ampanihy
# Processing Record 48 of Set 13 | bilma
# Processing Record 49 of Set 13 | matay
# Processing Record 50 of Set 13 | moultrie
# Processing Record 1 of Set 14 | najran
# Processing Record 2 of Set 14 | verkhnevilyuysk
# Processing Record 3 of Set 14 | los llanos de aridane
# Processing Record 4 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 14 | katangli
# Processing Record 6 of Set 14 | nikel
# Processing Record 7 of Set 14 | villacarrillo
# Processing Record 8 of Set 14 | sencha
# Processing Record 9 of Set 14 | nanma
# Processing Record 10 of Set 14 | bathsheba
# Processing Record 11 of Set 14 | san pedro de ycuamandiyu
# Processing Record 12 of Set 14 | kijang
# Processing Record 13 of Set 14 | petrolina
# Processing Record 14 of Set 14 | brae
# Processing Record 15 of Set 14 | paso de los toros
# Processing Record 16 of Set 14 | vrangel
# Processing Record 17 of Set 14 | hantsport
# Processing Record 18 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 14 | samatau
# City not found. Skipping...
# Processing Record 20 of Set 14 | vanavara
# Processing Record 21 of Set 14 | ossora
# Processing Record 22 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 14 | pantai remis
# Processing Record 24 of Set 14 | sharanga
# Processing Record 25 of Set 14 | isla vista
# Processing Record 26 of Set 14 | labuhan
# Processing Record 27 of Set 14 | la paz
# Processing Record 28 of Set 14 | lucea
# Processing Record 29 of Set 14 | cururupu
# Processing Record 30 of Set 14 | taoudenni
# Processing Record 31 of Set 14 | pahrump
# Processing Record 32 of Set 14 | ko samui
# Processing Record 33 of Set 14 | adelaide
# Processing Record 34 of Set 14 | yaring
# Processing Record 35 of Set 14 | delhi
# Processing Record 36 of Set 14 | sabang
# Processing Record 37 of Set 14 | sampit
# Processing Record 38 of Set 14 | fundacion
# Processing Record 39 of Set 14 | huarmey
# Processing Record 40 of Set 14 | lianran
# Processing Record 41 of Set 14 | dingle
# Processing Record 42 of Set 14 | zhifang
# Processing Record 43 of Set 14 | salmon creek
# Processing Record 44 of Set 14 | chengde
# Processing Record 45 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 46 of Set 14 | berlevag
# Processing Record 47 of Set 14 | chirongui
# Processing Record 48 of Set 14 | esna
# Processing Record 49 of Set 14 | santa rosa
# Processing Record 50 of Set 14 | kutum
# Processing Record 1 of Set 15 | vohma
# Processing Record 2 of Set 15 | rafai
# Processing Record 3 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 4 of Set 15 | noyabrsk
# Processing Record 5 of Set 15 | tibati
# Processing Record 6 of Set 15 | junin
# Processing Record 7 of Set 15 | punta cardon
# Processing Record 8 of Set 15 | lewistown
# Processing Record 9 of Set 15 | casper
# Processing Record 10 of Set 15 | salair
# Processing Record 11 of Set 15 | mbaiki
# Processing Record 12 of Set 15 | agadir
# Processing Record 13 of Set 15 | vostok
# Processing Record 14 of Set 15 | sioux lookout
# Processing Record 15 of Set 15 | koungou
# Processing Record 16 of Set 15 | derzhavinsk
# Processing Record 17 of Set 15 | tucuma
# Processing Record 18 of Set 15 | gusinoye ozero
# Processing Record 19 of Set 15 | talcahuano
# Processing Record 20 of Set 15 | bolgatanga
# Processing Record 21 of Set 15 | riedlingen
# Processing Record 22 of Set 15 | letka
# Processing Record 23 of Set 15 | gorodets
# Processing Record 24 of Set 15 | sangar
# Processing Record 25 of Set 15 | tipuani
# Processing Record 26 of Set 15 | ratnagiri
# Processing Record 27 of Set 15 | west bay
# Processing Record 28 of Set 15 | bullingen
# City not found. Skipping...
# Processing Record 29 of Set 15 | grand forks
# Processing Record 30 of Set 15 | pevek
# Processing Record 31 of Set 15 | okhotsk
# Processing Record 32 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 33 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 15 | bardiyah
# Processing Record 35 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 36 of Set 15 | altay
# Processing Record 37 of Set 15 | bowen
# Processing Record 38 of Set 15 | bollnas
# Processing Record 39 of Set 15 | tambun
# Processing Record 40 of Set 15 | dhidhdhoo
# Processing Record 41 of Set 15 | caernarfon
# Processing Record 42 of Set 15 | marawi
# Processing Record 43 of Set 15 | manay
# Processing Record 44 of Set 15 | komsomolets
# Processing Record 45 of Set 15 | boguchany
# Processing Record 46 of Set 15 | port shepstone
# Processing Record 47 of Set 15 | mansa
# Processing Record 48 of Set 15 | hofn
# Processing Record 49 of Set 15 | mirina
# City not found. Skipping...
# Processing Record 50 of Set 15 | saint-pierre
# Processing Record 1 of Set 16 | beringovskiy
# Processing Record 2 of Set 16 | buckeye
# Processing Record 3 of Set 16 | iralaya
# Processing Record 4 of Set 16 | bilibino
# Processing Record 5 of Set 16 | ixtapa
# Processing Record 6 of Set 16 | kerman
# Processing Record 7 of Set 16 | kachikau
# City not found. Skipping...
# Processing Record 8 of Set 16 | clarence town
# Processing Record 9 of Set 16 | ust-tsilma
# Processing Record 10 of Set 16 | keuruu
# Processing Record 11 of Set 16 | salistea
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Policarpo      PH  12.1791  125.5072     83.44        68          63
# 1        Rikitea      PF -23.1203 -134.9692     77.76        71           1
# 2           Lebu      CL -37.6167  -73.6500     51.58        92           8
# 3    Yellowknife      CA  62.4560 -114.3525     16.32        53          75
# 4      Carnarvon      AU -24.8667  113.6333     95.07        28          71
# 5          Bluff      NZ -46.6000  168.3333     54.81        66          31
# 6   Kruisfontein      ZA -34.0033   24.7314     53.31        80          67
# 7        Kismayo      SO  -0.3582   42.5454     82.11        79          85
# 8         Avarua      CK -21.2078 -159.7750     82.45        78          27
# 9    Clyde River      CA  70.4692  -68.5914    -16.37        76          75
#
#    Wind Speed       Description
# 0        6.71     broken clouds
# 1       14.12         clear sky
# 2       11.79         clear sky
# 3        5.75     broken clouds
# 4        8.05     broken clouds
# 5       30.33  scattered clouds
# 6        4.38     broken clouds
# 7        6.46   overcast clouds
# 8        3.44  scattered clouds
# 9        4.61        light snow

# %%
# Export the DataFrame as a CSV file
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
